# %% [markdown]
# ### Intalling libs

# %%
# pip install pydotplus
# pip install umap
# pip uninstall umap --yes
# pip install umap-learn
# pip install phate

# %% [markdown]
# ### Column description
#
# | Variável 	| Descrição 	|
# |:-:	|:-	|
# | PassangerID 	| ID de identificação do passageiro(a) 	|
# | Survived 	| se o passageiro(a) sobreviveu (0 = não, 1 = sim) 	|
# | Pclass 	| classe do passageiro:<br>     * **1 = primeira**,<br>     * **2 = segunda**,<br>     * **3 = terceira** 	|
# | name 	| nome do passageiro(a) 	|
# | sex 	| sexo do passageiro(a) 	|
# | age 	| idade do passageiro(a) 	|
# | Sibsp 	| número de irmão(ãs)/esposo(a) à bordo 	|
# | Parch 	| número de pais/filhos(as) à bordo 	|
# | Ticket 	| número da passagem 	|
# | Fare 	| preço da passagem 	|
# | Cabin 	| cabine 	|
# | Embarked 	| local que o passageiro(a) embarcou:<br>     * **C = Cherboug**,<br>     * **Q = Queenstown**,<br>     * **S = Southamption** 	|
# | WikiId 	| ID de identificação do passageiro(a) segundo Wikipedia 	|
# | Name_wiki 	| nome do passageiro(a) 	|
# | Age_wiki 	| idade do passageiro(a) 	|
# | Hometown 	| cidade de nascimento do passageiro(a) 	|
# | Boarded 	| cidade de embarque 	|
# | Destination 	| destino da viagem 	|
# | Lifeboat 	| identificação do bote salva-vidas 	|
# | Body 	| número de identificação do corpo 	|
#
#
# <font color='red'>**IMPORTANT**</font>
#
# The new features (the ones after 'Embarked') are very similar to the original ones but they are more up-to-date and have much fewer missing values. Therefore, users can decide on the preferred features themselves.

# %% [markdown]
# ### Importing Libs

# %%
# dataset import
from sklearn.datasets import (
    load_boston
)

# data visualization
# %matplotlib inline
import seaborn as sns

import matplotlib.pyplot as plt

from seaborn import (
    jointplot,
    pairplot,
    boxplot,
    heatmap
)

from yellowbrick.features import (
    Rank2D, 
    RadViz,
    FeatureImportances,
    ParallelCoordinates,
    JointPlotVisualizer,
)

import dtreeviz

import pydotplus

from io import(
    StringIO
)

from IPython.display import (
    Image
)

# data manipulation
import numpy as np
import pandas as pd
from pandas.plotting import(
    radviz
)

import janitor as jn

from ydata_profiling import ProfileReport

from sklearn.decomposition import PCA

from sklearn.preprocessing import (
    StandardScaler
)

from yellowbrick.features.pca import (
    PCADecomposition
)

import umap.umap_ as umap

from sklearn.manifold import TSNE

import phate

# missing values
import missingno as msno

from sklearn.impute import (
    SimpleImputer
)

# machine learning models
from sklearn import (
    svm,
    tree,
    impute,
    ensemble,
    preprocessing,
    model_selection
)

from sklearn.utils import (
    resample
)

from sklearn.dummy import (
    DummyClassifier
)

from sklearn.model_selection import (
    train_test_split
)

from sklearn.experimental import (
    enable_iterative_imputer
)

from sklearn.linear_model import (
    LogisticRegression,
    LinearRegression
)

from sklearn.naive_bayes import (
    GaussianNB
)

from sklearn.tree import (
    plot_tree,
    export_graphviz,
    DecisionTreeRegressor,
    DecisionTreeClassifier,
)

from sklearn.neighbors import (
    KNeighborsClassifier,
    KNeighborsRegressor
)

from sklearn.naive_bayes import (
    GaussianNB
)

from sklearn.svm import (
    SVC,
    SVR
)

from sklearn.ensemble import (
    RandomForestRegressor,
    RandomForestClassifier
)

from imblearn.over_sampling import (
    RandomOverSampler,
)

from sklearn.dummy import (
    DummyRegressor
)

import shap

import rfpimp

import lightgbm as lgb

import xgboost as xgb

from xgboost import (
    XGBRegressor
)

import xgbfir

# data model metrics
from lime import (
    lime_tabular
)

from treeinterpreter import (
    treeinterpreter as ti
)

from sklearn.metrics import (
    auc,
    f1_score,
    roc_curve,
    recall_score,
    roc_auc_score,
    accuracy_score,
    precision_score,
    confusion_matrix,
    average_precision_score
)

import scikitplot as skplt

from yellowbrick.classifier import (
    ROCAUC,
    ClassBalance,
    ConfusionMatrix,
    ClassPredictionError,
    ClassificationReport,
    PrecisionRecallCurve,
    DiscriminationThreshold,
)

from yellowbrick.regressor import (
    PredictionError
)

from yellowbrick.model_selection import (
    LearningCurve,
    ValidationCurve,
)

from scipy import (
    stats
)

# data prep-model
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    learning_curve
)

# model deploy
import pickle
# Out:
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/shap/plots/colors/_colorconv.py:819: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/shap/plots/colors/_colorconv.py:819: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/shap/plots/colors/_colorconv.py:819: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/shap/plots/colors/_colorconv.py:819: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
# ...

# %% [markdown]
# ### Reading the Titanic Dataset

# %%
df = pd.read_csv("titanic_dataset.csv", index_col=0)
df.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  WikiId  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   691.0
# 2                1      0          PC 17599  71.2833   C85        C    90.0
# ...

# %% [markdown]
# ### Deleting _Class_ feature at the end
# We are deleting because is the same as _pclass_ (same result, same data)

# %%
df = df.drop('Class', axis = 'columns')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Converting DataFrame Column Names to Lowercase snakecase

# %%
df.columns = (df.columns
                .str.replace('(?<=[a-z])(?=[A-Z])', '_', regex=True)
                .str.lower()
             )

df
# Out:
#              survived  pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           name     sex   age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Preparing the dataset

# %%
# dropping columns taht do not add value
df = df.drop(columns = ['name',
                        'name_wiki',
                        'wiki_id',
                        'hometown',
                        'destination',
                        'ticket',
                        'lifeboat',
                        'body',
                        'cabin',
                        'age'])

# using get_dummies function to convert object to int
df = pd.get_dummies(df)

# dropping redundant features
df = df.drop(columns = ['sex_male'])

#remove rows with any values that are not finite (NaN or infite)
df = df[np.isfinite(df).all(1)]

# first, we need to create a series of the target feature
y = df.survived

# then, we create a DataFrame with the attributes
X = df.drop(columns = ['survived'])

# using the scikit-learn to split 30% to test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
df.dtypes
# Out:
# survived               float64
# pclass                   int64
# sib_sp                   int64
# parch                    int64
# fare                   float64
# age_wiki               float64
# sex_female                bool
# embarked_C                bool
# embarked_Q                bool
# embarked_S                bool
# boarded_Belfast           bool
# boarded_Cherbourg         bool
# boarded_Queenstown        bool
# boarded_Southampton       bool
# dtype: object

# %%
'''
def tweak_titanic(df):
    df = df.drop(columns = ['name',
                        'name_wiki',
                        'wiki_id',
                        'hometown',
                        'destination',
                        'ticket',
                        'lifeboat',
                        'body',
                        'cabin',
                        'age'
        ]
    ).pipe(pd.get_dummies, drop_first=True)
    return df

def get_train_test_X_y(
    df, y_col, size=0.3, std_cols=None
):
    y = df[y_col]
    X = df.drop(columns=y_col)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, y, test_size=size, random_state=42
    )
    cols = X.columns
    num_cols = [
        "pclass",
        "age_wiki",
        "sib_sp",
        "parch",
        "fare",
    ]
    fi = impute.IterativeImputer()

    fitted = fi.fit_transform(X_train[num_cols])
    X_train = X_train.assign(**{c:fitted[:,i] for i, c in enumerate(num_cols)})
    test_fit = fi.transform(X_test[num_cols])
    X_test = X_test.assign(**{c:test_fit[:,i] for i, c in enumerate(num_cols)})
    if std_cols:
        std = preprocessing.StandardScaler()
        fitted = std.fit_transform(X_train[std_cols])
        X_train = X_train.assign(**{c:fitted[:,i] for i, c in enumerate(std_cols)})
        test_fit = std.transform(X_test[std_cols])
        X_test = X_test.assign(**{c:test_fit[:,i] for i, c in enumerate(std_cols)})

    return X_train, X_test, y_train, y_test

ti_df = tweak_titanic(df)
std_cols = "pclass,age_wiki,sib_sp,fare".split(",")
X_train, X_test, y_train, y_test = get_train_test_X_y(
    ti_df, "survived", std_cols=std_cols
)


X = pd.concat([X_train, X_test])
y = pd.concat([y_train, y_test])
'''
# Out:
# '\ndef tweak_titanic(df):\n    df = df.drop(columns = [\'name\',\n                        \'name_wiki\',\n                        \'wiki_id\',\n                        \'hometown\',\n                        \'destination\',\n                        \'ticket\',\n                        \'lifeboat\',\n                        \'body\',\n                        \'cabin\',\n                        \'age\'\n        ]\n    ).pipe(pd.get_dummies, drop_first=True)\n    return df\n\ndef get_train_test_X_y(\n    df, y_col, size=0.3, std_cols=None\n):\n    y = df[y_col]\n    X = df.drop(columns=y_col)\n    X_train, X_test, y_train, y_test = model_selection.train_test_split(\n        X, y, test_size=size, random_state=42\n    )\n    cols = X.columns\n    num_cols = [\n        "pclass",\n        "age_wiki",\n        "sib_sp",\n        "parch",\n        "fare",\n    ]\n    fi = impute.IterativeImputer()\n\n    fitted = fi.fit_transform(X_train[num_cols])\n    X_train = X_train.assign(**{c:fitted[:,
# ...

# %%
X.isnull().sum()
# Out:
# pclass                 0
# sib_sp                 0
# parch                  0
# fare                   0
# age_wiki               0
# sex_female             0
# embarked_C             0
# embarked_Q             0
# embarked_S             0
# boarded_Belfast        0
# boarded_Cherbourg      0
# boarded_Queenstown     0
# boarded_Southampton    0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Dimensionality Reduction
# There are several techniques for decomposing attributes into a smaller subset. This can be convenient for exploratory data analysis, visualizations, building predictive models, or clustering.

# %%
'''
# dataset
ti_df = tweak_titanic(df)

std_cols = "pclass,age_wiki,sib_sp,fare".split(",")

X_train, X_test, y_train, y_test = get_train_test_X_y(
    ti_df, "survived", std_cols=std_cols
)

X = pd.concat([X_train, X_test])
y = pd.concat([y_train, y_test])
'''
# Out:
# '\n# dataset\nti_df = tweak_titanic(df)\n\nstd_cols = "pclass,age_wiki,sib_sp,fare".split(",")\n\nX_train, X_test, y_train, y_test = get_train_test_X_y(\n    ti_df, "survived", std_cols=std_cols\n)\n\nX = pd.concat([X_train, X_test])\ny = pd.concat([y_train, y_test])\n'

# %% [markdown]
# ### PCA
# Principal Component Analysis uses a matrix (X) of rows (samples) and columns (attributes). It returns a new matrix whose columns are linear combinations of the original columns. These linear combinations maximize variance.<br><br>
# Each column is orthogonal to the others (has a right angle), and they are ordered according to decreasing variance.<br><br>
# **scikit-learn** has an implementation for this model. It's better to standardize the data before running it. After calling the *.fit* method, we will have access to an attribute *.explained_variance_ratio* that lists the percentage of variance in each column.<br><br>
# **PCA** is convenient for visualizing data in two or three dimensions. It is also used as a data pre-processing step to filter random noise. It is suitable for identifying global but not local structures, and works well with linear data.

# %%
pca = PCA(random_state=42)
X_pca = pca.fit_transform(
    StandardScaler().fit_transform(X)
)

pca.explained_variance_ratio_
# Out:
# array([2.82169742e-01, 1.99318818e-01, 1.38007169e-01, 1.06111046e-01,
#        7.99506469e-02, 6.43110875e-02, 4.90953795e-02, 4.13204412e-02,
#        2.65220573e-02, 1.08551478e-02, 1.95578715e-03, 3.82677925e-04,
#        4.14252252e-32])

# %%
pca.components_[0]
# Out:
# array([-0.1225408 , -0.04426943, -0.02850749,  0.15651814,  0.02592785,
#         0.10187386,  0.43588537,  0.18927072, -0.49988305, -0.00312829,
#         0.43704465,  0.18858417, -0.49434654])

# %% [markdown]
# **Instance parameters**<br>
# *n_components=None*
# - number of components to be generated. If equal to *None*, returns the same number corresponding to the number of columns<br>
#
# *copy=True*
# - will modify data in .fit if True
#
# *whiten=False*
# - will clean data after transformation to ensure uncorrelated components
#
# *svd_solver='auto'*
# - 'auto' runs SVD 'randomized' if *n_components* is less than 80% of the smallest dimension (faster, but an approximation)
#
# *tol=0.0*
# - tolerance for unique values
#
# *iterated_power='auto'*
# - number of iterations for svd_solver 'randomized'
# <br><br>
#
# **Attributes**
#
# *components_*
# - principal components (weight columns of linear combinations for original attributes)
#
# *explained_variance_*
# - variance value for each component
#
# *explained_variance_ratio_*
# - variance value for each normalized component (sum is 1)
#
# *singular_values_*
# - unique values ​​for each component
#
# *mean*
# - average of each attribute
#
# *n_components_*
# - if *n_components* is a floating point number, this will be the number of components
#
# *noise_variance_*
# - estimated noise covariance

# %% [markdown]
# The graph of the cumulative sum of the explained variance ratio is called *scree plot*.<br>
# This graph shows how much information is stored in the components. The *elbow method* can be used to see if it bends in order to determine how many components to use

# %%
fig, ax = plt.subplots(figsize=(6, 4))

ax.plot(pca.explained_variance_ratio_)
ax.set(
    xlabel="Component",
    ylabel="Percent of Explained Variance",
    title="Scree Plot",
    ylim=(0, 1)
)

fig.savefig("images/dimensionality_reduction_pca_scree_plot")

# %% [markdown]
# Another way to visualize this data is to use a *cumulative chart*. In this example, our original data had 8 columns, but looking at the graph, it appears that we will maintain approximately 90% of the variance if we only use 4 of the **PCA** components

# %%
fig, ax = plt.subplots(figsize=(6, 4))

ax.plot(
    np.cumsum(pca.explained_variance_ratio_)
)

ax.set(
    xlabel="Component",
    ylabel="Percent of Explained Variance",
    title="Cumulative Variance",
    ylim=(0, 1)
)

fig.savefig("images/dimensionality_reduction_pca_cumulative_chart")

# %% [markdown]
# We can use matplotlib's **imshow** function to analyze the impact that attributes have on components. <br>
# In this example, the darker the color, the greater the original column's contribution to the component.

# %%
fig, ax = plt.subplots(figsize=(6, 4))

plt.imshow(
    pca.components_.T,
    cmap="Spectral",
    vmin=-1,
    vmax=1
)

plt.yticks(range(len(X.columns)), X.columns)
plt.xticks(range(8), range(1, 9))
plt.xlabel("Principal Component")
plt.ylabel("Contribution")
plt.title(
    "Contribution of Features to Components"
)

plt.colorbar()

fig.savefig("images/dimensionality_reduction_pca_contribution_to_components_matplotlib")

# %% [markdown]
# If we have multiple attributes, we can limit the previous charts by only showing attributes that meet a minimum weight.

# %%
comps = pd.DataFrame(
    pca.components_, columns=X.columns
)

min_val = 0.5
num_components = 2
pca_cols = set()

for i in range (num_components):
    parts = comps.iloc[i][
        comps.iloc[i].abs() > min_val
    ]
    pca_cols.update(set(parts.index))

pca_cols
# Out:
# {'boarded_Queenstown', 'embarked_Q'}

# %% [markdown]
# **PCA** is generally used to visualize data sets with many dimensions into two components. We can visualize them in 2D. They will be colored according to survival status. Sometimes clusters may appear in the visualization.
#
# Using **Yellowbrick** to generate this visualization

# %%
y = y.astype(int)

# %%
fig, ax = plt.subplots(figsize=(14, 6))

colors = ["rg"[j] for j in y]

pca_viz = PCADecomposition(color=colors)
pca_viz.fit_transform(X, y)

fig.savefig("images/dimensionality_reduction_pca_clustering_yellowbrick")

# %% [markdown]
# Using **Seaborn** to generate this visualization

# %%
fig, ax = plt.subplots(figsize=(14, 6))

pca_df = pd.DataFrame(
    X_pca,
    columns=[
        f"PC{i+1}"
        for i in range(X_pca.shape[1])
    ],
)

pca_df["status"] = [
    ("deceased", "survived")[i] for i in y
]

evr = pca.explained_variance_ratio_

ax.set_aspect(evr[1] / evr[0])
sns.scatterplot(
    x="PC1",
    y="PC2",
    hue="status",
    data=pca_df,
    alpha=0.5,
    ax=ax
)

fig.savefig("images/dimensionality_reduction_pca_clustering_seaborn")

# %% [markdown]
# We can expand the scatterplot by showing a *loading plot* over it. This graph is called a **biplot** because it contains the scatter plot and the load plot.<br>
# Loadings show the strength of attributes and how they are correlated. If they form sharp angles, it is a sign that they are probably correlated. If the angles are 90 degrees, they are likely uncorrelated. Finally, if the angle between them is close to 180 degrees, there will be a negative correlation.

# %%
fig, ax = plt.subplots(figsize=(14, 6))

pca_df = pd.DataFrame(
    X_pca,
    columns=[
        f"PC{i+1}"
        for i in range(X_pca.shape[1])
    ],
)

pca_df["status"] = [
    ("deceased", "survived")[i] for i in y
]

evr = pca.explained_variance_ratio_

x_idx = 0 # x_pc
y_idx = 1 # y_pc

ax.set_aspect(evr[y_idx] / evr[x_idx])
x_col = pca_df.columns[x_idx]
y_col = pca_df.columns[y_idx]

sns.scatterplot(
    x=x_col, 
    y=y_col,
    hue="status",
    data=pca_df,
    alpha=0.5,
    ax=ax
)

scale = 8

comps = pd.DataFrame(
    pca.components_, columns=X.columns
)

for idx, s in comps.T.iterrows():
    plt.arrow(
        0,
        0,
        s[x_idx] * scale,
        s[y_idx] * scale,
        color="k"
    )
    plt.text(
        s[x_idx] * scale,
        s[y_idx] * scale,
        idx,
        weight="bold"
    )

fig.savefig("images/dimensionality_reduction_pca_clustering_biplot_seaborn")

# %% [markdown]
# ### UMAP
# Uniform Manifold Approximation and projection is a dimensionality reduction technique that uses *manifold learning*. Thus, it tends to put topologically similar items together and seeks to preserve both global and local structure, as opposed to *t-SNE*, which favors local structure.<br><br>
# Normalizing the attributes is a good idea to have the values on the same scale. **UMAP** is very sensitive to hyperparameters (*n_neighbors, min_dist, n_components or metric*)

# %%
u = umap.UMAP(random_state=42)

X_umap = u.fit_transform(
    StandardScaler().fit_transform(X)
)

X_umap.shape
# Out:
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# (887, 2)

# %% [markdown]
# **Instance Parameters**<br>
# *n_neighbors=15*
# - size of the local neighborhood. Higher values ​​imply a global view, while lower values ​​imply a more local view
#
# *n_components=2*
# - number of dimensions for embedding
#
# *metric='euclidean'*
# - metric used for distance. It could be a function that accepts two 1D arrays and returns a floating point number
#
# *n_epochs=None*
# - number of training epochs. The default will be 200 or 500, depending on the size of the dataset
#
# *learning_rate=1.0*
# - learning rate for embedding optimization
#
# *init='sprectral'*
# - startup type. Spectral embedding is the default. Can be 'random' or a numpy array of positions
#
# *min_dist=0.1*
# - between 0 and 1. Minimum distance between embedded points. Smaller values ​​mean more clumps, higher values ​​mean more dispersion
#
# *spread=1.0*
# - determines the distance between points after embedding
#
# *set_op_min_ratio=1.0*
# - between 0 and 1: fuzzy union (1) or fuzzy intersection (0)
#
# *local_connectivity=1.0*
# - number of neighbors for local connectivity. As this value increases, more local connections will be created
#
# *repulsion_strength=1.0*
# - repulsion force. Larger values ​​give more weight to negative samples
#
# *negative_sample_rate=5*
# - negative samples per positive sample. Larger values ​​introduce more repulsion, more optimization costs, and more accuracy
#
# *transform_queue_size=4.0*
# - aggressiveness in searching for nearest neighbors. A larger value has worse performance but will have greater accuracy
#
# *a=None*
# - parameter for embedding control. If equal to *None*, **UMAP** will determine the value from *min_dist* and *spread*
#
# *b=None*
# - parameter for embedding control. If equal to *None*, **UMAP** will determine the value from *min_dist* and *spread*
#
# *metric_kwds=None*
# - metric dictionary for additional parameters if a function is used for *metric*. Furthermore, *minkowsi* (and others) can be parameterized with this information
#
# *angular_rp_forest=False*
# - uses random angular projection
#
# *target_n_neighbors=-1*
# - number of neighbors for simplicial sets
#
# *target_metric_kwds=None*
# - dictionary of metrics to be used if a function is used in *tager_metric*
#
# *target_metric='categorical'*
# - to use supervised reduction. Can also be **L1** or **L2**
#
# *target_weight=0.5*
# - weighting factor. Between 0.0 and 1.0, where - means based on data only and 1 means based on target only<br><br>
#
# **Attributes**<br>
#
# *embedding_*
# - embedding results

# %%
fig, ax = plt.subplots(figsize=(14,6))

pd.DataFrame(X_umap).plot(
    kind="scatter",
    x=0,
    y=1,
    ax=ax,
    c=y,
    alpha=0.2,
    cmap="Spectral"
)

fig.savefig("images/dimensionality_reduction_umap_matplotlib")

# %% [markdown]
# We can adjust the **UMAP** result by focusing on the *n_neighbors* and *min_dist* hyperparameters.

# %%
# result of adjusted UMAP using n_neighbors
X_std = StandardScaler().fit_transform(X)

fig, axes = plt.subplots(2, 2, figsize=(6, 4))
axes = axes.reshape(4)

for i, n in enumerate([2, 5, 10, 50]):
    ax = axes[i]
    u = umap.UMAP(
        random_state=42, n_neighbors=n
    )
    X_umap = u.fit_transform(X_std)
    
    pd.DataFrame(X_umap).plot(
        kind="scatter",
        x=0,
        y=1,
        ax=ax,
        cmap="Spectral",
        alpha=0.5
    )
    ax.set_title(f"nn={n}")
    
plt.tight_layout()

fig.savefig("images/dimensionality_reduction_adjusted_umap_n_neighbors_matplotlib")
# Out:
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1258: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1258: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# ...

# %%
# result of adjusted UMAP using min_dist
fig, axes = plt.subplots(2, 2, figsize=(6, 4))
axes = axes.reshape(4)

for i, n in enumerate([0, 0.33, 0.66, 0.99]):
    ax = axes[i]
    u = umap.UMAP(
        random_state=42, min_dist=n
    )
    X_umap = u.fit_transform(X_std)
    
    pd.DataFrame(X_umap).plot(
        kind="scatter",
        x=0,
        y=1,
        ax=ax,
        cmap="Spectral",
        alpha=0.5
    )
    ax.set_title(f"min_dist={n}")
    
plt.tight_layout()

fig.savefig("images/dimensionality_reduction_adjusted_umap_min_dist_matplotlib")
# Out:
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1258: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1258: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# ...

# %% [markdown]
# ### t_SNE
# The t-SNE (t-Distributed Stochastic Neighboring Embedding) technique is a visualization and dimensionality reduction technique. It uses distributions of input data and embedding to have fewer dimensions, and minimizes the probability of joins between them. As it is very demanding from a processing point of view, it may not be possible to use this technique with a large data set.<br><br>
# A characteristic of **t-SNE** is that it is very sensitive to hyperparameters. Furthermore, although it preserves local clusters very well, global information is not preserved. Therefore, the distance between the clusters is not significant. Finally, this is not a deterministic algorithm, and there may be no convergence.<br><br>
# Standardizing the data before using the technique is advisable.

# %%
X_std = StandardScaler().fit_transform(X)

ts = TSNE()

X_tsne = ts.fit_transform(X_std)
# Out:
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.

# %% [markdown]
# **Instance parameters**<br>
# *n_components=2*
# - number of dimensions for embedding
#
# *perplexity=30.0*
# - suggested values ​​are between 5 and 50. Smaller numbers tend to create more rigid agglomerations
#
# *early_exaggeration=12.0*
# - controls the rigidity of the clusters and the spacing between them. Larger values ​​mean larger spacing
#
# *learning_rate=200.0*
# - in general, between 10 and 1000. If the data resembles a ball, reduce this value. If it looks compressed, elevate it
#
# *n_iter=1000*
# - number of iterations
#
# *n_iter_without_progress=300*
# - abort if there is no progress after this number of iterations
#
# *min_grad_norm=1e-07*
# - optimization will stop if the gradient norm is below this value
#
# *metric='euclidean'*
# - distance metric from *scipy.spatial.distance.pdist, pairwise.PAIRWISE_DISTANCE_METRIC* or a function
#
# *init='random'*
# - embedding initialization
#
# *method='barnes_hut'*
# - gradient calculation algorithm
#
# *angle=0.5*
# - for gradient calculation. A value less than 0.2 increases execution time. If it is greater than 0.8, the error will increase<br><br>
#
# **Attributes**<br>
#
# *embedding_*
# - embedding vectors
#
# *kl_divergence_*
# - Kullback-Leibler divergence
#
# *n_iter_*
# - number of iterations

# %% [markdown]
# Using *matplotlib* to plot **t-SNE** result

# %%
fig, ax = plt.subplots(figsize=(14, 6))
colors = ["rg"[j] for j in y]

scat = ax.scatter(
    X_tsne[:, 0],
    X_tsne[:, 1],
    c=colors,
    alpha=0.5
)

ax.set_xlabel("Embedding 1")
ax.set_ylabel("Embedding 2")

fig.savefig("images/dimensionality_reduction_tsne_matplotlib")

# %% [markdown]
# Changing the value of *perplexity* can have major effects on the graph

# %%
fig, axes = plt.subplots(2, 2, figsize=(6, 4))
axes = axes.reshape(4)

for i, n in enumerate((2, 30, 50, 100)):
    ax = axes[i]
    t = TSNE(random_state=42, perplexity=n)
    X_tsne = t.fit_transform(X)
    pd.DataFrame(X_tsne).plot(
        kind="scatter",
        x=0,
        y=1,
        ax=ax,
        c=y,
        cmap="Spectral",
        alpha=0.5
    )
    ax.set_title(f"perplexity={n}")

plt.tight_layout()

fig.savefig("images/dimensionality_reduction_adjusted_perplexity_tsne_matplotlib")
# Out:
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
# ...

# %% [markdown]
# ### PHATE
# **PHATE** (Potential of Heat-diffusion for Affinity-based Trajectory Embedding) is a tool for visualizing data with many dimensions. It tends to maintain both global structure (like **PCA**) and local structure (like **t-SNE**).<br>
#
# **PHATE** initially encodes local information (points close to each other must remain close). It uses "diffusion" to discover global data and then reduces dimensionality.

# %%
p = phate.PHATE(random_state=42)

X_phate = p.fit_transform(X)

X_phate.shape
# Out:
# Calculating PHATE...
#   Running PHATE on 887 observations and 13 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating optimal t...
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/phate/phate.py:802: DeprecationWarning: Call to deprecated method info. (Use TaskLogger.log_info instead) -- Deprecated since version 1.1.0.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/graphtools/graphs.py:290: RuntimeWarning: Detected zero distance between 104 pairs of samples. Consider removing duplicates to avoid errors in downstream processing.
#     Automatically selected t = 19
#   Calculated optimal t in 0.23 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.15 seconds.
#   Calculating metric MDS...
# ...

# %% [markdown]
# **Instance parameters**<br>
#
# *n_components=2*
# - number of dimensions
#
# *knn=5*
# - number of neighbors for the kernel. Increase if embedding is disconnected or dataset has more than 100k samples
#
# *decay=40*
# - kernel drop rate. Reducing this value increases graph connectivity
#
# *n_landmark=2000*
# - landmarks to be used
#
# *t='auto'*
# - diffusion power. A smoothing is done on the data. Increase this value if the embedding lacks structure. Decrease if the structure is rigid and compact
#
# *gamma=1*
# - logarithmic potential (between -1 and 1). If the embeddings are concentrated around a single point, try setting this value to 0
#
# *n_pca=100*
# - number of main components for neighborhood calculation
#
# *knn_dist='euclidian'*
# - KNN metric
#
# *mds_dist='euclidian'*
# - MDS (multidimensional scaling) metric
#
# *mds='metric'*
# - MDS algorithm for dimension reduction
#
# *n_jobs=1*
# - number of CPUs to be used<br><br>
#
#
# **Attributes**<br>
#
# *X*
# - input data
#
# *embedding*
# - embedding space
#
# *diff_op*
# - broadcast operator
#
# *graph*
# - KNN graph built from input data

# %%
fig, ax = plt.subplots(figsize=(6, 4))

phate.plot.scatter2d(p, c=y, ax=ax, alpha=0.5)

fig.savefig("images/dimensionality_reduction_phate_matplotlib")
# Out:
# /var/folders/vb/yxjjx1m94n93ty4t50m8f2b40000gn/T/ipykernel_15352/2672746520.py:3: DeprecationWarning: Call to deprecated function (or staticmethod) scatter2d. (Use scprep.plot.scatter2d instead) -- Deprecated since version 1.0.0.

# %% [markdown]
# We can adjust the *knn* parameter

# %%
fig, axes = plt.subplots(2, 2, figsize=(6, 4))
axes = axes.reshape(4)

p = phate.PHATE(random_state=42, n_jobs=-1)

for i, n in enumerate((2, 5, 20, 100)):
    ax = axes[i]
    p.set_params(knn=n)
    X_phate = p.fit_transform(X)
    pd.DataFrame(X_phate).plot(
        kind='scatter',
        x=0,
        y=1,
        ax=ax,
        c=y,
        cmap="Spectral",
        alpha=0.5
    )
    ax.set_title(f"knn={n}")

plt.tight_layout()

fig.savefig("images/dimensionality_reduction_adjusted_knn_phate_matplotlib")
# Out:
# Calculating PHATE...
#   Running PHATE on 887 observations and 13 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating optimal t...
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/phate/phate.py:802: DeprecationWarning: Call to deprecated method info. (Use TaskLogger.log_info instead) -- Deprecated since version 1.1.0.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/graphtools/graphs.py:290: RuntimeWarning: Detected zero distance between 104 pairs of samples. Consider removing duplicates to avoid errors in downstream processing.
# /Users/dellacorte/opt/anaconda3/lib/python3.9/site-packages/graphtools/graphs.py:454: RuntimeWarning: overflow encountered in power
#     Automatically selected t = 78
#   Calculated optimal t in 0.19 seconds.
# ...

# %%
#
